# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>1.Dataset about employement(UN)</h3>

# %%
df1=pd.read_csv("~/data_viz/Project_Employement/data/raw_data/UN_data/UNdata_Export_employ.csv")
df1.head()
# Out:
#   Country or Area  Year                  Sex Classification  \
# 0         Tunisia  1989  Total men and women     ISIC-Rev.2
# 1         Tunisia  1989  Total men and women     ISIC-Rev.2
# 2         Tunisia  1989  Total men and women     ISIC-Rev.2
# 3         Tunisia  1989  Total men and women     ISIC-Rev.2
# 4         Tunisia  1989  Total men and women     ISIC-Rev.2
#
#                                Subclassification               Source  \
# 0                                         Total.  Labour force survey
# 1  1. Agriculture, Hunting, Forestry and Fishing  Labour force survey
# 2                        2. Mining and Quarrying  Labour force survey
# 3                               3. Manufacturing  Labour force survey
# 4                                5. Construction  Labour force survey
#
#   SourceID   Value Value Footnotes Value Footnotes.1
# 0      # 0  1978.8               1                 1
# 1      # 0   509.7               1                 1
# ...

# %%
df1["Sex"].value_counts()
df1["Year"].value_counts()
_=df1["Subclassification"].value_counts()

# %%
df1_1=df1.drop(columns=['Country or Area','Classification','Source','SourceID','Value Footnotes','Value Footnotes.1'])
df1_1.shape
# Out:
# (231, 4)

# %%
df1_1=df1_1.dropna()
df1_1.shape
# Out:
# (228, 4)

# %% [markdown]
# <h3>2.Dataset about unemployement (UN)</h3>

# %%
df2=pd.read_csv("~/data_viz/Project_Employement/data/raw_data/UN_data/UNdata_Export_unemploy.csv")
df2.head()
# Out:
#   Country or Area  Year                  Sex        Coverage  \
# 0         Tunisia  2005  Total men and women  Total coverage
# 1         Tunisia  2005                  Men  Total coverage
# 2         Tunisia  2005                Women  Total coverage
# 3         Tunisia  2005         Rates, total  Total coverage
# 4         Tunisia  2005           Rates, men  Total coverage
#
#                 Source SourceID        Type  Value Value Footnotes  \
# 0  Labour force survey      # 0  Unemployed  486.4             1,2
# 1  Labour force survey      # 0  Unemployed  328.8             1,2
# 2  Labour force survey      # 0  Unemployed  157.6             1,2
# 3  Labour force survey      # 0  Unemployed   14.2             1,2
# 4  Labour force survey      # 0  Unemployed   13.1             1,2
#
#   Value Footnotes.1
# 0               1,2
# 1               1,2
# 2               1,2
# 3               1,2
# 4               1,2

# %%
df2["Coverage"].value_counts()
df2["Year"].value_counts()
df2["Sex"].value_counts()
# df2["Type"].value_counts()
# Out:
# Total men and women    73
# Men                    60
# Women                  45
# Rates, women            9
# Rates, men              9
# Rates, total            9
# Name: Sex, dtype: int64

# %%
df2_1=df2.drop(columns=['Country or Area','Source','SourceID','Value Footnotes','Value Footnotes.1'])
df2_1.shape
# Out:
# (211, 5)

# %%
df2_1=df2_1.dropna()
df2_1.shape
# Out:
# (205, 5)

# %% [markdown]
# <h3>3.Dataset about occupied active population by sex</h3>

# %%
df_Population_A_1=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/Population active/Evolution de la population active occupée selon le sexe.xlsx",
                                header=1)
df_Population_A_1
# Out:
#                                                   .1  II trimestre 2011  \
# 0  Evolution de la population active occupée  Nombre             3139.8
# 1        Population active occupée Masculine  Nombre             2394.1
# 2         Population active occupée Féminine  Nombre              745.7
#
#    IV trimestre 2011  I trimestre 2012  II trimestre 2012  III trimestre 2012  \
# 0             3170.7            3207.1             3231.6              3242.9
# 1             2405.0            2423.9             2434.9              2444.3
# 2              765.7             783.2              796.7               798.6
#
#    IV trimestre 2012  I trimestre 2013  II trimestre 2013  ...  \
# 0             3255.8            3281.2             3315.3  ...
# 1             2451.0            2466.0             2482.4  ...
# 2              804.8             815.2              832.9  ...
#
#    III trimestre 2017  IV trimestre 2017  I trimestre 2018  II trimestre 2018  \
# ...

# %%
df_Population_A_1_1=df_Population_A_1.drop(columns=[" .1"])

# %%
df_Population_A_1_1=df_Population_A_1_1.T

# %%
df_Population_A_1_1.to_csv('~/data_viz/Project_Employement/data/tidy_data/Population active/Evolution de la population active occupée selon le sexe.csv')

# %% [markdown]
# <h3>4.Dataset about active population by sex</h3>

# %%
df_Population_A_2=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/Population active/Evolution de la population active selon le sexe.xlsx",
                                header=1)
df_Population_A_2
# Out:
#                                                     .1  II trimestre 2011  \
# 0            Evolution de la population active  Nombre             3844.6
# 1  Evolution de la population active Masculine  Nombre             2817.9
# 2   Evolution de la population active Féminine  Nombre             1026.7
#
#    IV trimestre 2011  I trimestre 2012  II trimestre 2012  III trimestre 2012  \
# 0             3909.1            3916.9             3923.2              3907.9
# 1             2842.1            2849.7             2852.3              2844.4
# 2             1067.0            1067.2             1070.9              1063.5
#
#    IV trimestre 2012  I trimestre 2013  II trimestre 2013  ...  \
# 0             3909.6            3927.3             3943.7  ...
# 1             2847.4            2864.4             2862.0  ...
# 2             1062.2            1062.9             1081.7  ...
#
#    III trimestre 2017  IV trimestre 2017  I trimestre 2018  II trimestre 2018  \
# ...

# %%
df_Population_A_2_1=df_Population_A_2.drop(columns=[" .1"])
df_Population_A_2_1=df_Population_A_2_1.T

# %%
df_Population_A_2_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/Population active/Evolution de la population active selon le sexe.csv")

# %% [markdown]
# <h3>5.Dataset about 15 years old > </h3>

# %%
df_Population_O_1=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/Population occupée/Evolution de la population en âge d'activité (15 ans et plus) selon le sexe.xlsx",
                                header=1)
df_Population_O_1
# Out:
#                                                           .1  \
# 0  Evolution de la population en âge d'activité (...  Nombre
# 1  Evolution de la population Masculine (15 ans e...  Nombre
# 2  Evolution de la population Féminine (15 ans et...  Nombre
#
#    II trimestre 2011  IV trimestre 2011  I trimestre 2012  II trimestre 2012  \
# 0             8146.6             8175.2            8190.5             8211.7
# 1             4019.1             4027.4            4045.7             4056.4
# 2             4127.5             4147.8            4144.8             4155.3
#
#    III trimestre 2012  IV trimestre 2012  I trimestre 2013  II trimestre 2013  \
# 0              8255.8             8282.7            8294.6             8315.7
# 1              4062.0             4073.5            4077.7             4086.4
# 2              4193.8             4209.2            4216.9             4229.3
#
#    ...  III trimestre 2017  IV trimestre 2017  I trimestre 2018  \
# ...

# %%
df_Population_O_1_1=df_Population_O_1.drop(columns=[" .1"])
df_Population_O_1_1=df_Population_O_1_1.T

# %%
df_Population_O_1_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/Population occupée/Evolution de la population en âge d'activité (15 ans et plus) selon le sexe.csv")

# %% [markdown]
# <h3>6.Evolution des créations d'emploi selon le sexe</h3>

# %%
df_Population_O_2=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/Population occupée/Evolution des créations d'emploi selon le sexe.xlsx",
                                header=1)
df_Population_O_2
# Out:
#                                               .1  II trimestre 2011  \
# 0       Evolution des créations d'emploi  Nombre             -137.6
# 1  Créations d'emploi pour les Masculins  Nombre              -63.7
# 2   Créations d'emploi pour les Féminins  Nombre              -73.9
#
#    IV trimestre 2011  I trimestre 2012  II trimestre 2012  III trimestre 2012  \
# 0               30.9              36.4               24.5                11.3
# 1               10.9              18.9               11.0                 9.4
# 2               20.0              17.5               13.5                 1.9
#
#    IV trimestre 2012  I trimestre 2013  II trimestre 2013  ...  \
# 0               12.9              25.4               34.1  ...
# 1                6.7              15.0               16.4  ...
# 2                6.2              10.4               17.7  ...
#
#    III trimestre 2017  IV trimestre 2017  I trimestre 2018  II trimestre 2018  \
# ...

# %%
df_Population_O_2_1=df_Population_O_2.drop(columns=[" .1"])
df_Population_O_2_1=df_Population_O_2_1.T

# %%
df_Population_O_2_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/Population occupée/Evolution des créations d'emploi selon le sexe.csv")

# %% [markdown]
# <h3>7.Répartition de la population active occupée selon le secteur d'activité</h3>

# %%
df_Population_O_3=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/Population occupée/Répartition de la population active occupée selon le secteur d'activité.xlsx",
                                header=1)
df_Population_O_3.head()
# Out:
#                                                           .1  \
# 0  Répartition de la population active occupée se...  Nombre
# 1  Population active occupée dans Agriculture et ...  Nombre
# 2  Population active occupée dans l'Industries ma...  Nombre
# 3  Population active occupée dans l'Industries ag...  Nombre
# 4  Population active occupée dans les matériaux d...  Nombre
#
#    II trimestre 2011  IV trimestre 2011  I trimestre 2012  II trimestre 2012  \
# 0             3139.8             3170.7            3207.1             3231.6
# 1              510.0              534.5             543.2              550.0
# 2              578.0              572.7             604.8              597.9
# 3               72.3               68.2              77.5               78.2
# 4               35.0               37.1              40.7               39.4
#
#    III trimestre 2012  IV trimestre 2012  I trimestre 2013  II trimestre 2013  \
# ...

# %%
df_Population_O_3_1=df_Population_O_3.drop([0]).drop(columns=[" .1"])
df_Population_O_3_1[' '] = df_Population_O_3_1[' '].map(lambda x: str(x)[30:])
df_Population_O_3_1.head()
# Out:
#                                              II trimestre 2011  \
# 1                      Agriculture et pêche              510.0
# 2              l'Industries manufacturières              578.0
# 3             l'Industries agroalimentaires               72.3
# 4            les matériaux de constructions               35.0
# 5    l'Industries mécaniques et électriques              119.1
#
#    IV trimestre 2011  I trimestre 2012  II trimestre 2012  III trimestre 2012  \
# 1              534.5             543.2              550.0               504.9
# 2              572.7             604.8              597.9               600.4
# 3               68.2              77.5               78.2                85.3
# 4               37.1              40.7               39.4                39.8
# 5              124.0             126.4              123.4               125.2
#
#    IV trimestre 2012  I trimestre 2013  II trimestre 2013  III trimestre 2013  \
# ...

# %%
df_Population_O_3_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/Population occupée/Répartition de la population active occupée selon le secteur d'activité.csv")

# %% [markdown]
# <h3>8.Evolution de la population active en chômage selon le sexe</h3>

# %%
df_Population_Ch_1=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/chomage/Evolution de la population active en chômage selon le sexe.xlsx",
                                header=1)
df_Population_Ch_1
# Out:
#                                                      .1  II trimestre 2011  \
# 0  Evolution de la population active en chômage  Nombre              704.9
# 1        Population active en chômage Masculine  Nombre              423.8
# 2         Population active en chômage Féminine  Nombre              281.1
#
#    IV trimestre 2011  I trimestre 2012  II trimestre 2012  III trimestre 2012  \
# 0              738.4             709.7              691.6               665.0
# 1              437.1             425.7              417.4               400.1
# 2              301.3             284.0              274.2               264.9
#
#    IV trimestre 2012  I trimestre 2013  II trimestre 2013  ...  \
# 0              653.8             646.1              628.4  ...
# 1              396.4             398.4              379.6  ...
# 2              257.4             247.7              248.8  ...
#
#    III trimestre 2017  IV trimestre 2017  I trimestre 2018  II trimestre 2018  \
# ...

# %%
df_Population_Ch_1_1=df_Population_Ch_1.drop(columns=[" .1"])
df_Population_Ch_1_1=df_Population_Ch_1_1.T

# %%
df_Population_Ch_1_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/chomage/Evolution de la population active en chômage selon le sexe.csv")

# %% [markdown]
# <h3>9.Taux de chômage des diplômés de l’enseignement supérieur selon le genre</h3>

# %%
df_Population_Ch_2=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/chomage/Taux de chômage des diplômés de l’enseignement supérieur selon le genre.xlsx",
                                header=1)
df_Population_Ch_2
# Out:
#                                                                .1  \
# 0  Taux de chômage des diplômés de l’enseignement...  Pourcentage
# 1  Taux de chômage des Masculins des diplômés de ...  Pourcentage
# 2  Taux de chômage des Féminins des diplômés de l...  Pourcentage
#
#    II trimestre 2011  IV trimestre 2011  I trimestre 2012  II trimestre 2012  \
# 0               33.6               33.1              34.2               26.9
# 1               23.7               22.6              21.0               15.8
# 2               43.8               44.2              49.4               40.2
#
#    III trimestre 2012  IV trimestre 2012  I trimestre 2013  II trimestre 2013  \
# 0                32.7               33.2              33.2               31.6
# 1                20.6               20.6              22.6               20.9
# 2                46.4               47.5              45.3               43.5
#
#    ...  III trimestre 2017  IV trimestre 2017  I trimestre 2018  \
# ...

# %%
df_Population_Ch_2_1=df_Population_Ch_2.drop(columns=[" .1"])
df_Population_Ch_2_1=df_Population_Ch_2_1.T

# %%
df_Population_Ch_2_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/chomage/Taux de chômage des diplômés de l’enseignement supérieur selon le genre.csv")

# %% [markdown]
# <h3>9.Taux de chômage selon le sexe</h3>

# %%
df_Population_Ch_3=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/chomage/Taux de chômage selon le sexe.xlsx",
                                header=1)
df_Population_Ch_3
# Out:
#                                                      .1  II trimestre 2011  \
# 0  Emploi\Chômage\Taux de chômage\Par sexe  Pourcentage               18.3
# 1                 Taux de chômage Masculin  Pourcentage               15.0
# 2                  Taux de chômage Féminin  Pourcentage               27.4
#
#    IV trimestre 2011  I trimestre 2012  II trimestre 2012  III trimestre 2012  \
# 0               18.9              18.1               17.6                17.0
# 1               15.4              14.9               14.6                14.1
# 2               28.2              26.6               25.6                24.9
#
#    IV trimestre 2012  I trimestre 2013  II trimestre 2013  ...  \
# 0               16.7              16.5               15.9  ...
# 1               13.9              13.9               13.3  ...
# 2               24.2              23.3               23.0  ...
#
#    III trimestre 2017  IV trimestre 2017  I trimestre 2018  II trimestre 2018  \
# ...

# %%
df_Population_Ch_3_1=df_Population_Ch_3.drop(columns=[" .1"])
df_Population_Ch_3_1=df_Population_Ch_3_1.T

# %%
df_Population_Ch_3_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/chomage/Taux de chômage selon le sexe.csv")

# %% [markdown]
# <h3>10.Two datasets about bureau d'étude</h3>

# %%
df_Population_Be_1=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/bureau d'emploi/Socio économique 02_22_2020 22_04_20.xlsx",
                                header=1)
df_Population_Be_1.head()
# Out:
#                                                           .1    2007    2008  \
# 0       Evolution des demandes d'emploi enregistrées  Nombre  522082  565907
# 1  Evolution des demandes d'emploi enregistrées p...  Nombre  522082  565907
# 2       Demandes d'emploi enregistrées des Masculins  Nombre  257589  273957
# 3        demandes d'emploi enregistrées des Feminins  Nombre  264493  291950
# 4                              Dont première demande  Nombre  447946  494571
#
#      2009    2010    2011    2012    2013    2014    2015    2016    2017
# 0  547879  604327  802421  864744  735933  691969  701676  789927  657543
# 1  547879  604327  802421  864743  735933  691969  701676  789927  657543
# 2  252491  270754  365751  381176  330451  299110  308416  343261  263500
# 3  295388  333573  436670  483567  405482  392859  393260  446666  394043
# 4  482485  543842  747698  812738  688132  652043  663636  753015  630750

# %%
df_Population_Be_1_1=df_Population_Be_1.drop(df_Population_Be_1.index[1]).drop(columns=[" .1"])
df_Population_Be_1_1=df_Population_Be_1_1.T

# %%
df_Population_Be_1_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/bureau d'emploi/Socio économique 02_22_2020 22_04_20.csv")

# %%
df_Population_Be_2=pd.read_excel("~/data_viz/Project_Employement/data/raw_data/bureau d'emploi/Socio économique 02_22_2020 22_12_13.xlsx",
                                header=1)
df_Population_Be_2.head()
# Out:
#                                             .1    2007    2008    2009  \
# 0  Evolution des offres d'emploi reçus  Nombre  142042  147466  159893
# 1        Placements réalisées par Sexe  Nombre  124572  134224  131403
# 2  Placements réalisées  des Masculins  Nombre   71399   75548   73000
# 3    Placements réalisées des Feminins  Nombre   53173   58676   58403
# 4                  Dont premier emploi  Nombre   78841   91805   92649
#
#      2010    2011    2012   2013    2014   2015   2016   2017
# 0  176196  100364  106321  93710  100486  78937  81071  86096
# 1  123421   46471   53643  58165   61484  55374  49460  49667
# 2   66182   22286   26043  26033   27150  23078  20778  19308
# 3   57239   24185   27600  32132   34334  32296  28682  30359
# 4   87837   37622   45416  51173   54883  49970  44975  45941

# %%
df_Population_Be_2_1=df_Population_Be_2.drop(columns=[" .1"])
df_Population_Be_2_1=df_Population_Be_2_1.T

# %%
df_Population_Be_2_1.to_csv("~/data_viz/Project_Employement/data/tidy_data/bureau d'emploi/Socio économique 02_22_2020 22_12_13.csv")
